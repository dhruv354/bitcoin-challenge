# %%
#import necessary files
import pandas as pd
import numpy as np

df = pd.read_csv('./mempool.csv')
df.head()
# Out:
#                                                tx_id  fee  weight  \
# 0  2e3da8fbc1eaca8ed9b7c2db9e6545d8ccac3c67deadee...  452    1620
# 1  79c51c9d4124c5cbb37a85263748dcf44e182dff83561f...  682    1136
# 2  b0ef627c8dc2a706475d33d7712209ec779f7a8302aaea...  226     900
# 3  8c25f9be93990b96e8bc363778d6debee6867c7d73cefa...  258    1032
# 4  edc82751537be6afcb21c0229d8d20916d8e742a363ab2...  452    1616
#
#                                             parents
# 0                                                NaN
# 1  6eb38fad135e38a93cb47a15a5f953cbc0563fd84bf1ab...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5214 entries, 0 to 5213
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tx_id     5214 non-null   object
#  1   fee       5214 non-null   int64
#  2   weight    5214 non-null   int64
#  3   parents   2000 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 163.1+ KB

# %%
block_sample = pd.read_csv('./block_sample.csv', header=None, names=['id'])
block_sample.head()
df_subset = df[df.tx_id.isin(block_sample.id)]
df_subset
# Out:
#                                                   tx_id   fee  weight parents
# 384   87a3591b694e91d039e680a2b3a89c8cec1c9d3a20b7f1...   678     896      NaN
# 450   fd53eae3cdd426e8f4896e6a602eb37f47060d9cac7974...   678     892      NaN
# 625   362ef0cb5dbfb247c9452b1e552e2cdb465cfa9316f5a0...   678     900      NaN
# 694   1f93ca96a8f21c30c1ac4ea080c63a806c3a2c0db41ea2...  1119    1480      NaN
# 898   52b171a32f3dc9fd3a50a871594049f8b7861a60d3c97b...   729     768      NaN
# ...                                                 ...   ...     ...      ...
# 5189  a801aeb0c6a81bea5fff456363756ba5489631c394b89e...  2325    1980      NaN
# 5195  9f7bdce93431eaef0d2e39dfa3c0bc44ded0483236c014...  2938     764      NaN
# 5197  89c055c073c1d3f20bf9c9e50aefce8f1db17b5738323b...  5140    1028      NaN
# 5201  3695562e80cd5b994f334b3880605e751fd85f88bf5fef...   904     892      NaN
# 5202  a3fc9fa1b766633f6efe3a360da96fa9414c3c97b6239a...   764     904      NaN
#
# [456 rows x 4 columns]

# %%
df.columns
df.columns = df.columns.str.replace(' ', '')

# %%
df.columns
# Out:
# Index(['tx_id', 'fee', 'weight', 'parents'], dtype='object')

# %%
df_subset.weight.sum()
# Out:
# 526580

# %%
df.weight.max()
# Out:
# 295164

# %%
df.dtypes
# Out:
# tx_id       object
# fee          int64
# weight       int64
# parents     object
# dtype: object

# %%
#convert each column to a list
tx_id = list(df.tx_id)
fee = list(df.fee)
weight = list(df.weight)
parents = list(df.parents.astype('str'))

# %%
parents
# Out:
# [nan,
#  '6eb38fad135e38a93cb47a15a5f953cbc0563fd84bf1abdec578c2af302e10bf',
#  nan,
#  nan,
#  nan,
#  'edc82751537be6afcb21c0229d8d20916d8e742a363ab235b5556c5fa698cf4f',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '50d949aaf11386f7f073ead1dbd7c39d9604e3c993738a8dcbbd7ea33a8862cf',
#  'e9729cc3da87c37f1a3cc11d8ad2b5c4e15dfc028dace8613e8a0e6e4cbc4d37',
#  nan,
#  nan,
#  nan,
#  nan,
#  '7ddb85d2922cda6c186f18e4b3f722b79a8c03f7dbf20ebcf8e08ab8fb2b2d89',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '70d17688f907f8cedd7a4aa8abfb9db728db9de84052a76fe908d7800ba7aa5b',
#  '2f1b8da0deba8d742f24c721e44248a9f0a5420e196e43fe35174a3fface6817',
#  nan,
#  'a8fa3e2c641f84f0d19f289433bd348086b167f83924b892d1d81ae8c27fb08b',
#  '14d5439e913b2ed2dda1b0a03e29a463db3357f159609e8f5f27b714b7d1eed1',
#  nan,
#  nan,
#  nan,
#  '30331b9553fc41cfd25a414dab84997e4eb3c4641ad97fcae396b72ed61d21f2',
#  nan,
#  nan,
# ...

# %%
#lets first check if there is more than one parent transaction for any txt_id
sample = pd.DataFrame(df.parents[df.parents.notnull()], columns=['parents'])
sample['len'] = sample.parents.apply(lambda x: x.count(';')+1 )

# %%
sample[sample.len > 1]
# Out:
#                                                 parents  len
# 526   288ea91bb52d8cb28289f4db0d857356622e39e78f33f2...    3
# 832   b01fa42f80e0b08b6cceb6fc1bef8b4e1e32610d6249a4...    2
# 978   2b9bda4206a67789347d21277b6ebd742e1db2126f085b...    3
# 993   09be9248e1ada7943bd03736fa84d3c5b7ea6fd8851876...    4
# 1094  032b0d0c3f879df5f26f9d427ed6b6978695b26f47e35d...    3
# 1097  1f49c5a9aba3e910f7b18c43f282294629b182c4ddd143...    2
# 1146  2bd5dd7d3d3452b7933ecaa434c73d6ab13ed5591b1a79...    3
# 1322  022932aa0c052cf51a4a4485508db7ba3ff0f09b6daca5...    5
# 1469  396b15f856ce55cba0a7d20af3a7b770bd4e1e66fa75de...    2
# 1484  1714890da5a8ca050aea7404b5f58550f6719c50acb7e5...    2
# 1527  3b42d1308d0f95211493f6962750b836af729091a6a62f...    2
# 1530  1477f7f7930171ea40d6637be5c9b485c43a20c67108c0...    2
# 2047  072991abd82c76031b767fd9d8742e8a8b0e4c432663e6...    2
# 2248  265d9fb70f753bf58316aab96021d30e0447383fc6c708...    3
# ...

# %%
#these are the txt_id with more than one unconfirmed parent transaction

# %%
#lets convert parents into 2D list for better access
parents_new = []
for parent in parents:
    parents_new.append(parent.split(';'))

# %%
parents_new[526]
# Out:
# ['288ea91bb52d8cb28289f4db0d857356622e39e78f33f26bf6df2bbdd3810fad',
#  'b5b993bda3c23bdefe4a1cf75b1f7cbdfe43058f2e4e7e25898f449375bb685c',
#  'c1ae3a82e52066b670e43116e7bfbcb6fa0abe16088f920060fa41e09715db7d']

# %%
#
